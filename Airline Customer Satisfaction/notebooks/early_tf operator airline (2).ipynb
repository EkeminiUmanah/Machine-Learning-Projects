# %% [markdown]
# #### Before we proceed, let's check that we're using the right image, that is, TensorFlow is available:

# %%
#! pip3 list | grep tensorflow 
#! pip3 install --user tensorflow==2.4.0
#! pip3 install --user ipywidgets nbconvert
#!python -m pip install --user --upgrade pip
#!pip3 install pandas scikit-learn keras tensorflow-datasets --user

# %% [markdown]
# #### To package the trainer in a container image, we shall need a file (on our cluster) that contains the code as well as a file with the resource definitition of the job for the Kubernetes cluster:

# %%
TRAINER_FILE = "tfjobairline.py"
KUBERNETES_FILE = "tfjob-airline.yaml"

# %% [markdown]
# #### We also want to capture output from a cell with %%capture that usually looks like some-resource created. To that end, let's define a helper function:

# %%
import re

from IPython.utils.capture import CapturedIO


def get_resource(captured_io: CapturedIO) -> str:
    """
    Gets a resource name from `kubectl apply -f <configuration.yaml>`.

    :param str captured_io: Output captured by using `%%capture` cell magic
    :return: Name of the Kubernetes resource
    :rtype: str
    :raises Exception: if the resource could not be created
    """
    out = captured_io.stdout
    matches = re.search(r"^(.+)\s+created", out)
    if matches is not None:
        return matches.group(1)
    else:
        raise Exception(f"Cannot get resource as its creation failed: {out}. It may already exist.")

# %% [markdown]
# #### Load and Inspect the Data¶

# %%
import pandas as  pd
data = pd.read_csv("https://raw.githubusercontent.com/Soot3/testing/master/Invistico_Airline.csv")
data.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               0  ...               2                       3
# 1               0  ...               2                       3
# 2               0  ...               2                       2
# 3               0  ...               3                       1
# 4               0  ...               4                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 3                 0                 3                5
# 1                 4                 4                 4                2
# 2                 3                 3                 4                4
# 3                 1                 0                 1                4
# 4                 2                 0                 2                4
#
#    Cleanliness  Online boarding  Departure Delay in Minutes  \
# 0            3                2                           0
# 1            3                2                         310
# 2            4                2                           0
# 3            1                3                           0
# 4            2                5                           0
#
#    Arrival Delay in Minutes
# 0                       0.0
# 1                     305.0
# 2                       0.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Train the Model in the Notebook
#
# We want to train the model in a distributed fashion, we put all the code in a single cell. That way we can save the file and include it in a container image:

# %%
import argparse
import logging
import json
import os
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from numpy.random import seed

import tensorflow as tf
tf.random.set_seed(221)
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

logging.basicConfig(
    format="%(asctime)s %(levelname)-8s %(message)s",
    datefmt="%Y-%m-%dT%H:%M:%SZ",
    level=logging.INFO)

# Import dependencies
import datetime
from tensorflow.keras import callbacks

# Create new callback
class MyHistory(callbacks.Callback):
    """Adapted from https://github.com/keras-team/keras/blob/master/keras/callbacks/callbacks.py#L614"""

    def on_train_begin(self, logs=None):
        self.epoch = []
        self.timestamps = []
        self.history = {}

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.epoch.append(epoch)
        self.timestamps.append(datetime.datetime.now())
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)


def make_datasets_unbatched():
    df = pd.read_csv("https://raw.githubusercontent.com/Soot3/testing/master/Invistico_Airline.csv")
    #drop rows with missing values
    df.dropna(inplace=True)
    #new column total delay
    df['total_delay'] = df['Departure Delay in Minutes'] + df['Arrival Delay in Minutes']
    
    #drop 'Departure Delay in Minutes',and 'Arrival Delay in Minutes'
    df.drop(columns=['Departure Delay in Minutes','Arrival Delay in Minutes'], inplace=True)
    
        #satisfied and dissatisfied in number 
    satisfaction_map = {"satisfied": 1,"dissatisfied": 0 }
    df['satisfaction']  = df['satisfaction'].map(satisfaction_map)

    #Male and Female in number 
    Gender_map = {"Male": 1,"Female": 2 }
    df['Gender']  = df['Gender'].map(Gender_map)

    #Loyal and disloyal in number 
    Customer_Type_map = {"Loyal Customer": 1,"disloyal Customer": 0 }
    df['Customer Type']  = df['Customer Type'].map(Customer_Type_map)

    #Business travel and Business travel in number 
    Type_of_Travel_map = {"Business travel": 1,"Personal Travel": 2 }
    df['Type of Travel']  = df['Type of Travel'].map(Type_of_Travel_map)

    #Business and Eco and Eco plus in number 
    Class_map = {"Business": 1,"Eco": 3, "Eco Plus": 2 }
    df['Class']  = df['Class'].map(Class_map)

    cols = ['Flight Distance', 'total_delay', 'Checkin service', 'On-board service']

    Q1 = df[cols].quantile(0.25)
    Q3 = df[cols].quantile(0.75)
    IQR = Q3 - Q1

    df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]   
    
    #Split dataset

    X = df.drop('satisfaction',axis=1)
    y = df['satisfaction'] 
    X_train,X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 111)
    
    
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
    train = train_dataset.cache().shuffle(2000).repeat()
    return train, test_dataset

def model(args):
    seed(1)
    model = Sequential()
    model.add(Dense(100, activation='relu', input_dim=21))
    model.add(BatchNormalization())
    model.add(Dense(40, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    
    model.summary()
    opt = args.optimizer
    model.compile(optimizer=opt,
                loss='binary_crossentropy',
                metrics=['accuracy'])
    tf.keras.backend.set_value(model.optimizer.learning_rate, args.learning_rate)
    return model


def main(args):
    # MultiWorkerMirroredStrategy creates copies of all variables in the model's
    # layers on each device across all workers
    strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy(
        communication=tf.distribute.experimental.CollectiveCommunication.AUTO)
    logging.debug(f"num_replicas_in_sync: {strategy.num_replicas_in_sync}")
    BATCH_SIZE_PER_REPLICA = args.batch_size
    BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync
    
    # Datasets need to be created after instantiation of `MultiWorkerMirroredStrategy`
    train_dataset, test_dataset = make_datasets_unbatched()
    train_dataset = train_dataset.batch(batch_size=BATCH_SIZE)
    test_dataset = test_dataset.batch(batch_size=BATCH_SIZE)

    # See: https://www.tensorflow.org/api_docs/python/tf/data/experimental/DistributeOptions
    options = tf.data.Options()
    options.experimental_distribute.auto_shard_policy = \
    tf.data.experimental.AutoShardPolicy.DATA
    
    train_datasets_sharded  = train_dataset.with_options(options)
    test_dataset_sharded = test_dataset.with_options(options)
    
    # Instantiate callback
    myHistory = MyHistory()
    
    with strategy.scope():
        # Model building/compiling need to be within `strategy.scope()`.
        multi_worker_model = model(args)
        # Keras' `model.fit()` trains the model with specified number of epochs and
        # number of steps per epoch. 
        multi_worker_model.fit(train_datasets_sharded,
                         epochs=100,
                         steps_per_epoch=100, callbacks = [myHistory])

        eval_loss, eval_acc = multi_worker_model.evaluate(test_dataset_sharded, 
                                                    verbose=0, steps=70)
        # Log metrics for Katib
        logging.info("loss={:.4f}".format(eval_loss))
        for i in myHistory.history['accuracy']:
          logging.info('accuracy = {:.4f}'.format(i))

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument("--batch_size",
                      type=int,
                      default=79,
                      metavar="N",
                      help="Batch size for training (default: 79)")
    parser.add_argument("--learning_rate", 
                      type=float,  
                      default=0.01,
                      metavar="N",
                      help='Initial learning rate')
    parser.add_argument("--optimizer", 
                      type=str, 
                      default='adam',
                      metavar="N",
                      help='optimizer')
    parsed_args, _ = parser.parse_known_args()
    main(parsed_args)m',
                      metavar="N",
                      help='optimizer')
    parsed_args, _ = parser.parse_known_args()
    main(parsed_args)
# Out:
# Overwriting tfjobairline.py

# %% [markdown]
# #### That saves the file as defined by TRAINER_FILE but it does not run it.
#
# Let's see if our code is correct by running it from within our notebook:

# %%
# %run $TRAINER_FILE --optimizer 'adam'
# Out:
# WARNING:tensorflow:From /home/jovyan/sooter_katib/tfjobairline.py:99: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# 2021-07-19T14:43:27Z WARNING  From /home/jovyan/sooter_katib/tfjobairline.py:99: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# INFO:tensorflow:Using MirroredStrategy with devices ('/device:CPU:0',)
# 2021-07-19T14:43:27Z INFO     Using MirroredStrategy with devices ('/device:CPU:0',)
# INFO:tensorflow:Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:CPU:0',), communication = CommunicationImplementation.AUTO
# 2021-07-19T14:43:27Z INFO     Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:CPU:0',), communication = CommunicationImplementation.AUTO
# 2021-07-19T14:43:28Z INFO     NumExpr defaulting to 2 threads.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                4040
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 6,681
# Trainable params: 6,481
# Non-trainable params: 200
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 5s 8ms/step - loss: 0.6395 - accuracy: 0.6509
# Epoch 2/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4476 - accuracy: 0.8040
# Epoch 3/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4363 - accuracy: 0.8100
# Epoch 4/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4114 - accuracy: 0.8198
# Epoch 5/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3977 - accuracy: 0.8290
# Epoch 6/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3810 - accuracy: 0.8357
# Epoch 7/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3737 - accuracy: 0.8397
# Epoch 8/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3670 - accuracy: 0.8421
# Epoch 9/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4024 - accuracy: 0.8204
# Epoch 10/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3636 - accuracy: 0.8401
# Epoch 11/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3894 - accuracy: 0.8327
# Epoch 12/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3786 - accuracy: 0.8350
# Epoch 13/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3778 - accuracy: 0.8328
# Epoch 14/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3728 - accuracy: 0.8367
# Epoch 15/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3685 - accuracy: 0.8406
# Epoch 16/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3526 - accuracy: 0.8449
# Epoch 17/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3692 - accuracy: 0.8397
# Epoch 18/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3608 - accuracy: 0.8475
# Epoch 19/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3485 - accuracy: 0.8490
# Epoch 20/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3519 - accuracy: 0.8421
# Epoch 21/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3450 - accuracy: 0.8539
# Epoch 22/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3381 - accuracy: 0.8513
# Epoch 23/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3349 - accuracy: 0.8563
# Epoch 24/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3170 - accuracy: 0.8616
# Epoch 25/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3144 - accuracy: 0.8635
# Epoch 26/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3347 - accuracy: 0.8559
# Epoch 27/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3162 - accuracy: 0.8649: 0s - loss: 0.3152 - accuracy: 0.
# Epoch 28/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3155 - accuracy: 0.8569
# Epoch 29/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3034 - accuracy: 0.8706
# Epoch 30/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2884 - accuracy: 0.8750
# Epoch 31/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3044 - accuracy: 0.8677
# Epoch 32/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3038 - accuracy: 0.8645
# Epoch 33/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2920 - accuracy: 0.8679
# Epoch 34/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2893 - accuracy: 0.8812
# Epoch 35/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2894 - accuracy: 0.8707
# Epoch 36/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2744 - accuracy: 0.8781
# Epoch 37/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2906 - accuracy: 0.8767
# Epoch 38/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2859 - accuracy: 0.8816
# Epoch 39/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2805 - accuracy: 0.8791
# Epoch 40/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2690 - accuracy: 0.8878
# Epoch 41/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2608 - accuracy: 0.8896
# Epoch 42/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2742 - accuracy: 0.8806
# Epoch 43/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2711 - accuracy: 0.8881
# Epoch 44/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2809 - accuracy: 0.8763
# Epoch 45/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2519 - accuracy: 0.8926
# Epoch 46/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2500 - accuracy: 0.8913
# Epoch 47/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2521 - accuracy: 0.8928
# Epoch 48/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2640 - accuracy: 0.8874
# Epoch 49/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2478 - accuracy: 0.8987
# Epoch 50/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2658 - accuracy: 0.8841
# Epoch 51/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2591 - accuracy: 0.8875
# Epoch 52/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2615 - accuracy: 0.8908: 0s - loss: 0.2610 - accuracy: 0.
# Epoch 53/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2507 - accuracy: 0.8914
# Epoch 54/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2547 - accuracy: 0.8885
# Epoch 55/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2531 - accuracy: 0.8848
# Epoch 56/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2703 - accuracy: 0.8750
# Epoch 57/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2414 - accuracy: 0.8949
# Epoch 58/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2554 - accuracy: 0.8851
# Epoch 59/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2637 - accuracy: 0.8883
# Epoch 60/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2489 - accuracy: 0.8932: 0s - loss: 0.2485 - accuracy: 0.89
# Epoch 61/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2819 - accuracy: 0.8857
# Epoch 62/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2622 - accuracy: 0.8854
# Epoch 63/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2491 - accuracy: 0.8908: 0s - loss: 0.2520 - accu
# Epoch 64/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2843 - accuracy: 0.8800: 0s - loss: 0.2845 - accuracy: 0.87
# Epoch 65/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2442 - accuracy: 0.8961
# Epoch 66/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2486 - accuracy: 0.8930: 0s - loss: 0.2492 - accuracy: 0.
# Epoch 67/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2436 - accuracy: 0.8993
# Epoch 68/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2568 - accuracy: 0.8869
# Epoch 69/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2257 - accuracy: 0.9080
# Epoch 70/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2526 - accuracy: 0.8952
# Epoch 71/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2403 - accuracy: 0.8932
# Epoch 72/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2628 - accuracy: 0.8883
# Epoch 73/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2540 - accuracy: 0.8898: 0s - loss: 0.2546 - accuracy:
# Epoch 74/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2600 - accuracy: 0.8838
# Epoch 75/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2447 - accuracy: 0.8955: 0s - loss: 0.2432 - accuracy: 0.
# Epoch 76/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2463 - accuracy: 0.8877
# Epoch 77/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2403 - accuracy: 0.9002
# Epoch 78/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2532 - accuracy: 0.8845
# Epoch 79/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2488 - accuracy: 0.8898
# Epoch 80/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2528 - accuracy: 0.8853
# Epoch 81/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2599 - accuracy: 0.8888
# Epoch 82/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2460 - accuracy: 0.8927
# Epoch 83/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2511 - accuracy: 0.8859
# Epoch 84/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2501 - accuracy: 0.8907
# Epoch 85/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2283 - accuracy: 0.9030
# Epoch 86/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2544 - accuracy: 0.8882
# Epoch 87/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2385 - accuracy: 0.8951
# Epoch 88/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2393 - accuracy: 0.8966
# Epoch 89/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2573 - accuracy: 0.8928
# Epoch 90/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2357 - accuracy: 0.8897
# Epoch 91/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2310 - accuracy: 0.8982
# Epoch 92/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2589 - accuracy: 0.8905
# Epoch 93/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2270 - accuracy: 0.9062
# Epoch 94/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2414 - accuracy: 0.8888
# Epoch 95/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2366 - accuracy: 0.8954
# Epoch 96/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2393 - accuracy: 0.8961
# Epoch 97/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2596 - accuracy: 0.8881
# Epoch 98/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2364 - accuracy: 0.8985
# Epoch 99/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2374 - accuracy: 0.8961
# Epoch 100/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2399 - accuracy: 0.8989
# 2021-07-19T14:44:48Z INFO     loss=0.8553
# 2021-07-19T14:44:48Z INFO     accuracy=0.7682

# %% [markdown]
# #### Create a Distributed TFJob
#
#
# For large training jobs, we wish to run our trainer in a distributed mode. Once the notebook server cluster can access the Docker image from the registry, we can launch a distributed TF job.
#
# The specification for a distributed TFJob is defined using YAML:

# %%
# %%writefile $KUBERNETES_FILE
# apiVersion: "kubeflow.org/v1"
# kind: "TFJob"
# metadata:
#     name: "air4line"
#     namespace: sooter # your-user-namespace
# spec:
#     cleanPodPolicy: None
#     tfReplicaSpecs:
#         Worker:
#             replicas: 2
#             restartPolicy: OnFailure
#             template:
#                 metadata:
#                     annotations:
#                         sidecar.istio.io/inject: "false"
#                 spec:
#                     containers:
#                     - name: tensorflow
#                       # modify this property if you would like to use a custom image
#                      image: mavencodev7/tfjob_airline:v.0.3
#                       command:
#                           - "python"
#                           - "/tfjobairline.py"
#                           - "--batch_size=79"
#                           - "--learning_rate=0.01"
#                           - "--optimizer=adam"
# Out:
# Writing tfjob-airline.yaml

# %% [markdown]
# #### Let's deploy the distributed training job:

# %%
# %%capture tf_output --no-stderr
! kubectl create -f $KUBERNETES_FILE

# %%
TF_JOB = get_resource(tf_output)

# %% [markdown]
# ##### To see the job status, use the following command:

# %%
! kubectl describe $TF_JOB
# Out:
# Name:         airlineearly1
# Namespace:    sooter
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1
# Kind:         TFJob
# Metadata:
#   Creation Timestamp:  2021-07-19T17:59:49Z
#   Generation:          1
#   Managed Fields:
#     API Version:  kubeflow.org/v1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:spec:
#         .:
#         f:tfReplicaSpecs:
#           .:
#           f:Worker:
#             .:
#             f:replicas:
#             f:restartPolicy:
#             f:template:
#               .:
#               f:metadata:
#                 .:
#                 f:annotations:
#                   .:
#                   f:sidecar.istio.io/inject:
#               f:spec:
#     Manager:      kubectl-create
#     Operation:    Update
#     Time:         2021-07-19T17:59:49Z
#     API Version:  kubeflow.org/v1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:spec:
#         f:runPolicy:
#           .:
#           f:cleanPodPolicy:
#         f:successPolicy:
#         f:tfReplicaSpecs:
#           f:Worker:
#             f:template:
#               f:metadata:
#                 f:creationTimestamp:
#               f:spec:
#                 f:containers:
#       f:status:
#         .:
#         f:conditions:
#         f:replicaStatuses:
#           .:
#           f:Worker:
#         f:startTime:
#     Manager:         tf-operator.v1
#     Operation:       Update
#     Time:            2021-07-19T17:59:50Z
#   Resource Version:  5717427
#   Self Link:         /apis/kubeflow.org/v1/namespaces/sooter/tfjobs/airlineearly1
#   UID:               7c58887e-8134-40bf-a99c-72df25c4a2f3
# Spec:
#   Clean Pod Policy:  None
#   Tf Replica Specs:
#     Worker:
#       Replicas:        2
#       Restart Policy:  OnFailure
#       Template:
#         Metadata:
#           Annotations:
#             sidecar.istio.io/inject:  false
#         Spec:
#           Containers:
#             Command:
#               python
#               /tfjobairline.py
#               --batch_size=79
#               --learning_rate=0.01
#               --optimizer=adam
#             Image:  mavencodevv/tfjob_airline:v.0.9
#             Name:   tensorflow
# Status:
#   Conditions:
#     Last Transition Time:  2021-07-19T17:59:49Z
#     Last Update Time:      2021-07-19T17:59:49Z
#     Message:               TFJob airlineearly1 is created.
#     Reason:                TFJobCreated
#     Status:                True
#     Type:                  Created
#   Replica Statuses:
#     Worker:
#   Start Time:  2021-07-19T17:59:50Z
# Events:
#   Type    Reason                   Age   From         Message
#   ----    ------                   ----  ----         -------
#   Normal  SuccessfulCreatePod      4s    tf-operator  Created pod: airlineearly1-worker-0
#   Normal  SuccessfulCreatePod      3s    tf-operator  Created pod: airlineearly1-worker-1
#   Normal  SuccessfulCreateService  3s    tf-operator  Created service: airlineearly1-worker-0
#   Normal  SuccessfulCreateService  3s    tf-operator  Created service: airlineearly1-worker-1

# %%
! kubectl get pods -l job-name=airlineearly1
# Out:
# NAME                     READY   STATUS              RESTARTS   AGE
# airlineearly1-worker-0   1/1     Running             0          16s
# airlineearly1-worker-1   0/1     ContainerCreating   0          15s

# %%
! kubectl get events --sort-by='.lastTimestamp' | tail
# Out:
# 20s         Normal    SuccessfulCreateService   tfjob/airlineearly1                                                   Created service: airlineearly1-worker-0
# 20s         Normal    SuccessfulCreatePod       tfjob/airlineearly1                                                   Created pod: airlineearly1-worker-1
# 18s         Normal    Pulling                   pod/airlineearly1-worker-1                                            Pulling image "mavencodevv/tfjob_airline:v.0.9"
# 9s          Normal    Started                   pod/airlineearly1-worker-0                                            Started container tensorflow
# 9s          Normal    Created                   pod/airlineearly1-worker-0                                            Created container tensorflow
# 9s          Normal    Pulled                    pod/airlineearly1-worker-0                                            Successfully pulled image "mavencodevv/tfjob_airline:v.0.9" in 10.399618359s
# 5s          Warning   BackOff                   pod/airline2-end-to-end-qst4x9cn-worker-0                             Back-off restarting failed container
# 5s          Normal    Pulled                    pod/airlineearly1-worker-1                                            Successfully pulled image "mavencodevv/tfjob_airline:v.0.9" in 13.19221095s
# 2s          Normal    Created                   pod/airlineearly1-worker-1                                            Created container tensorflow
# 2s          Normal    Started                   pod/airlineearly1-worker-1                                            Started container tensorflow

# %% [markdown]
# To stream logs from the worker-0 pod to check the training progress, run the following command:

# %%
! kubectl logs -f airlineearly1-worker-0
# Out:
# 2021-07-19 18:00:07.321864: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-07-19 18:00:07.322475: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /tfjobairline.py:121: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# 2021-07-19T18:00:09Z WARNING  From /tfjobairline.py:121: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# 2021-07-19 18:00:09.077932: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 18:00:09.078558: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-07-19 18:00:09.078598: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-19 18:00:09.078729: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (airlineearly1-worker-0): /proc/driver/nvidia/version does not exist
# 2021-07-19 18:00:09.120077: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 18:00:09.155930: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 18:00:09.165702: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> airlineearly1-worker-0.sooter.svc:2222, 1 -> airlineearly1-worker-1.sooter.svc:2222}
# 2021-07-19 18:00:09.166333: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://airlineearly1-worker-0.sooter.svc:2222
# INFO:tensorflow:Enabled multi-worker collective ops with available devices: ['/job:worker/replica:0/task:0/device:CPU:0']
# 2021-07-19T18:00:09Z INFO     Enabled multi-worker collective ops with available devices: ['/job:worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:worker/task:0',)
# 2021-07-19T18:00:09Z INFO     Using MirroredStrategy with devices ('/job:worker/task:0',)
# INFO:tensorflow:Waiting for the cluster, timeout = inf
# 2021-07-19T18:00:09Z INFO     Waiting for the cluster, timeout = inf
# INFO:tensorflow:Cluster is ready.
# 2021-07-19T18:00:41Z INFO     Cluster is ready.
# INFO:tensorflow:MultiWorkerMirroredStrategy with cluster_spec = {'worker': ['airlineearly1-worker-0.sooter.svc:2222', 'airlineearly1-worker-1.sooter.svc:2222']}, task_type = 'worker', task_id = 0, num_workers = 2, local_devices = ('/job:worker/task:0',), communication = CommunicationImplementation.AUTO
# 2021-07-19T18:00:41Z INFO     MultiWorkerMirroredStrategy with cluster_spec = {'worker': ['airlineearly1-worker-0.sooter.svc:2222', 'airlineearly1-worker-1.sooter.svc:2222']}, task_type = 'worker', task_id = 0, num_workers = 2, local_devices = ('/job:worker/task:0',), communication = CommunicationImplementation.AUTO
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:44Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:44Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19 18:00:45.152098: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-19 18:00:45.154096: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2299995000 Hz
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:45Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 8 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:46Z INFO     Collective batch_all_reduce: 8 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:46Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:46Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:46Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:46Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 8 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 8 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:00:47Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dense_1 (Dense)              (None, 40)                4040
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 6,681
# Trainable params: 6,481
# Non-trainable params: 200
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 5s 9ms/step - loss: 0.5977 - accuracy: 0.6835
# Epoch 2/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.4134 - accuracy: 0.8210
# Epoch 3/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3872 - accuracy: 0.8366
# Epoch 4/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3725 - accuracy: 0.8446
# Epoch 5/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3926 - accuracy: 0.8283
# Epoch 6/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3721 - accuracy: 0.8430
# Epoch 7/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3681 - accuracy: 0.8396
# Epoch 8/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.3640 - accuracy: 0.8454
# Epoch 9/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3710 - accuracy: 0.8376
# Epoch 10/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3551 - accuracy: 0.8470
# Epoch 11/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3518 - accuracy: 0.8523
# Epoch 12/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3482 - accuracy: 0.8520
# Epoch 13/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3621 - accuracy: 0.8469
# Epoch 14/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.3402 - accuracy: 0.8553
# Epoch 15/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3325 - accuracy: 0.8612
# Epoch 16/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.3262 - accuracy: 0.8660
# Epoch 17/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.3110 - accuracy: 0.8687
# Epoch 18/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2996 - accuracy: 0.8694
# Epoch 19/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2989 - accuracy: 0.8721
# Epoch 20/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2944 - accuracy: 0.8758
# Epoch 21/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2825 - accuracy: 0.8793
# Epoch 22/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2800 - accuracy: 0.8784
# Epoch 23/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2737 - accuracy: 0.8837
# Epoch 24/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2638 - accuracy: 0.8871
# Epoch 25/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2581 - accuracy: 0.8902
# Epoch 26/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2689 - accuracy: 0.8874
# Epoch 27/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2512 - accuracy: 0.8912
# Epoch 28/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2618 - accuracy: 0.8882
# Epoch 29/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2491 - accuracy: 0.8927
# Epoch 30/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2560 - accuracy: 0.8839
# Epoch 31/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2570 - accuracy: 0.8922
# Epoch 32/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2474 - accuracy: 0.8909
# Epoch 33/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2387 - accuracy: 0.8943
# Epoch 34/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2482 - accuracy: 0.8949
# Epoch 35/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2288 - accuracy: 0.9032
# Epoch 36/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2484 - accuracy: 0.8914
# Epoch 37/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2485 - accuracy: 0.8949
# Epoch 38/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2416 - accuracy: 0.8937
# Epoch 39/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2516 - accuracy: 0.8927
# Epoch 40/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2381 - accuracy: 0.8987
# Epoch 41/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2531 - accuracy: 0.8951
# Epoch 42/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2483 - accuracy: 0.8894
# Epoch 43/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2342 - accuracy: 0.9015
# Epoch 44/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2461 - accuracy: 0.8916
# Epoch 45/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2467 - accuracy: 0.8974
# Epoch 46/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2349 - accuracy: 0.8960
# Epoch 47/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2251 - accuracy: 0.9070
# Epoch 48/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2438 - accuracy: 0.8943
# Epoch 49/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2506 - accuracy: 0.8935
# Epoch 50/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2352 - accuracy: 0.8977
# Epoch 51/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2382 - accuracy: 0.8960
# Epoch 52/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2430 - accuracy: 0.8944
# Epoch 53/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.2252 - accuracy: 0.9023
# Epoch 54/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2435 - accuracy: 0.8947
# Epoch 55/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2377 - accuracy: 0.8973
# Epoch 56/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2513 - accuracy: 0.8883
# Epoch 57/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2403 - accuracy: 0.8952
# Epoch 58/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2356 - accuracy: 0.8992
# Epoch 59/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.2393 - accuracy: 0.8981
# Epoch 60/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2275 - accuracy: 0.9026
# Epoch 61/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2315 - accuracy: 0.8986
# Epoch 62/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2329 - accuracy: 0.8983
# Epoch 63/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2268 - accuracy: 0.9027
# Epoch 64/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2348 - accuracy: 0.8990
# Epoch 65/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2306 - accuracy: 0.9004
# Epoch 66/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2273 - accuracy: 0.9041
# Epoch 67/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2383 - accuracy: 0.8984
# Epoch 68/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2276 - accuracy: 0.9026
# Epoch 69/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2392 - accuracy: 0.9012
# Epoch 70/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2501 - accuracy: 0.8963
# Epoch 71/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.2308 - accuracy: 0.8989
# Epoch 72/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2192 - accuracy: 0.9088
# Epoch 73/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2360 - accuracy: 0.9021
# Epoch 74/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2226 - accuracy: 0.9055
# Epoch 75/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2268 - accuracy: 0.9013
# Epoch 76/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2231 - accuracy: 0.9064
# Epoch 77/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2367 - accuracy: 0.8978
# Epoch 78/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2321 - accuracy: 0.9063
# Epoch 79/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2146 - accuracy: 0.9108
# Epoch 80/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2336 - accuracy: 0.9027
# Epoch 81/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2174 - accuracy: 0.9056
# Epoch 82/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2286 - accuracy: 0.9014
# Epoch 83/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2118 - accuracy: 0.9078
# Epoch 84/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2194 - accuracy: 0.9060
# Epoch 85/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2230 - accuracy: 0.9036
# Epoch 86/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2238 - accuracy: 0.9074
# Epoch 87/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2182 - accuracy: 0.9077
# Epoch 88/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2228 - accuracy: 0.9036
# Epoch 89/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2242 - accuracy: 0.9052
# Epoch 90/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2277 - accuracy: 0.9080
# Epoch 91/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2190 - accuracy: 0.9084
# Epoch 92/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2237 - accuracy: 0.9085
# Epoch 93/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2298 - accuracy: 0.9030
# Epoch 94/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2307 - accuracy: 0.9069
# Epoch 95/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2208 - accuracy: 0.9059
# Epoch 96/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2144 - accuracy: 0.9077
# Epoch 97/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2209 - accuracy: 0.9068
# Epoch 98/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2164 - accuracy: 0.9133
# Epoch 99/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2302 - accuracy: 0.9025
# Epoch 100/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2126 - accuracy: 0.9085
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:10Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:10Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:10Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:10Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# INFO:tensorflow:Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:10Z INFO     Collective batch_all_reduce: 1 all-reduces, num_devices = 1, group_size = 2, implementation = AUTO, num_packs = 1
# 2021-07-19T18:02:11Z INFO     loss=0.9516
# 2021-07-19T18:02:11Z INFO     accuracy = 0.7510
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8311
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8400
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8420
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8328
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8387
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8435
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8466
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8426
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8470
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8566
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8522
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8477
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8570
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8642
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8620
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8715
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8703
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8753
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8705
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8796
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8802
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8809
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8833
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8857
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8842
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8887
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8869
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8896
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8871
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8934
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8907
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8932
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8940
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8959
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8907
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8969
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8899
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8920
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8991
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8950
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8938
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8953
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8935
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8966
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8951
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8994
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8939
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8947
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9004
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8954
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8953
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8999
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8951
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9001
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8912
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8955
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8969
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8997
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9002
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8984
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9003
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9007
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9016
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8992
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9027
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9005
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9022
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8966
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9008
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9020
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9017
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9011
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9038
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9020
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9070
# 2021-07-19T18:02:11Z INFO     accuracy = 0.8988
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9075
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9036
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9024
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9039
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9041
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9027
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9073
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9053
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9056
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9010
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9050
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9087
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9078
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9080
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9068
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9045
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9076
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9046
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9081
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9072
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9122
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9058
# 2021-07-19T18:02:11Z INFO     accuracy = 0.9081

# %% [markdown]
# #### To delete the job, run the following command:

# %%
! kubectl delete $TF_JOB
# Out:
# tfjob.kubeflow.org "airlineearly" deleted

# %% [markdown]
# #### Check to see if the check to see if the pod is still up and running

# %%
#! kubectl -n sooter logs -f airline
